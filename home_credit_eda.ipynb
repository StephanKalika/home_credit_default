# %% [markdown]
# # Home Credit EDA

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import iqr, randint, uniform
import xgboost as xgb
import lightgbm as lgb
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegressionCV
from sklearn.preprocessing import Imputer, StandardScaler, RobustScaler
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, train_test_split, cross_val_score
from sklearn.metrics import roc_auc_score
from skopt import gp_minimize
from skopt.plots import plot_convergence, plot_objective
import warnings
import pickle
import gc

gc.enable()
warnings.filterwarnings("ignore")
np.random.seed(0)

# %%
application_train = pd.read_csv("/Users/danielsaxton/home_credit_default_risk/application_train.csv")
application_test = pd.read_csv("/Users/danielsaxton/home_credit_default_risk/application_test.csv")

# %%
bureau_balance = pd.read_csv("/Users/danielsaxton/home_credit_default_risk/bureau_balance.csv")
bureau = pd.read_csv("/Users/danielsaxton/home_credit_default_risk/bureau.csv")
credit_card = pd.read_csv("/Users/danielsaxton/home_credit_default_risk/credit_card_balance.csv")
installments = pd.read_csv("/Users/danielsaxton/home_credit_default_risk/installments_payments.csv")
pos_cash = pd.read_csv("/Users/danielsaxton/home_credit_default_risk/POS_CASH_balance.csv")
previous_application = pd.read_csv("/Users/danielsaxton/home_credit_default_risk/previous_application.csv")

# %% [markdown]
# df = pd.read_csv("/Users/danielsaxton/home_credit_default_risk/preprocessed_train.csv")

# %%
application_train.shape
# Out:
# (307511, 122)

# %%
application_train["SK_ID_CURR"].where(lambda x: x.isin(credit_card["SK_ID_CURR"])).dropna().shape
# Out:
# (86905,)

# %%
application_train["SK_ID_CURR"].where(lambda x: x.isin(pos_cash["SK_ID_CURR"])).dropna().shape
# Out:
# (289444,)

# %%
application_train["SK_ID_CURR"].where(lambda x: x.isin(installments["SK_ID_CURR"])).dropna().shape
# Out:
# (291643,)

# %% [markdown]
# ### Installments / POS / credit card
#
# * Paying down debt?  Aggregate to SK_ID_PREV level?
# * Rate of change, variance
# * Change in utilization

# %% [markdown]
# * For each credit card trade, get the change in average balance across 6 month intervals

# %%
installments.sort_values(["SK_ID_CURR", "SK_ID_PREV", "NUM_INSTALMENT_NUMBER"]).head(100).tail(20)
# Out:
#          SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# 470118      1692033      100007                     1.0
# 3349535     1692033      100007                     1.0
# 3797824     1692033      100007                     1.0
# 1421369     1692033      100007                     1.0
# 1350720     1692033      100007                     1.0
# 1337649     1692033      100007                     1.0
# 3713578     1692033      100007                     1.0
# 199642      1692033      100007                     1.0
# 3009235     1692033      100007                     1.0
# 3573177     1692033      100007                     1.0
# 3594951     1692033      100007                     1.0
# 2272701     1940724      100007                     1.0
# 2328091     1940724      100007                     1.0
# 1240665     1940724      100007                     1.0
# 3442072     1940724      100007                     1.0
# 2188051     1940724      100007                     1.0
# 3099936     1940724      100007                     1.0
# 1393228     1940724      100007                     1.0
# 575944      1940724      100007                     1.0
# 2773292     1940724      100007                     1.0
#
#          NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  \
# 470118                       2           -314.0              -317.0
# 3349535                      3           -284.0              -287.0
# 3797824                      4           -254.0              -258.0
# 1421369                      5           -224.0              -226.0
# 1350720                      6           -194.0              -198.0
# 1337649                      7           -164.0              -166.0
# 3713578                      8           -134.0              -136.0
# 199642                       9           -104.0              -106.0
# 3009235                     10            -74.0               -75.0
# 3573177                     11            -44.0               -44.0
# 3594951                     12            -14.0               -14.0
# 2272701                      1          -1076.0             -1074.0
# 2328091                      1          -1076.0             -1106.0
# 1240665                      2          -1046.0             -1046.0
# 3442072                      3          -1016.0             -1016.0
# 2188051                      4           -986.0              -987.0
# 3099936                      5           -956.0              -955.0
# 1393228                      6           -926.0              -926.0
# 575944                       7           -896.0              -896.0
# 2773292                      8           -866.0              -867.0
#
#          AMT_INSTALMENT  AMT_PAYMENT
# 470118        16037.640    16037.640
# 3349535       16037.640    16037.640
# 3797824       16037.640    16037.640
# 1421369       16037.640    16037.640
# 1350720       16037.640    16037.640
# 1337649       16037.640    16037.640
# 3713578       16037.640    16037.640
# 199642        16037.640    16037.640
# 3009235       16037.640    16037.640
# 3573177       16037.640    16037.640
# 3594951       16037.640    16037.640
# 2272701       22678.785    22655.655
# 2328091       22678.785       23.130
# 1240665       22678.785    22678.785
# 3442072       22678.785    22678.785
# 2188051       22678.785    22678.785
# 3099936       22678.785    22678.785
# 1393228       22678.785    22678.785
# 575944        22678.785    22678.785
# 2773292       22678.785    22678.785

# %%
pos_cash.sort_values(["SK_ID_CURR", "SK_ID_PREV", "MONTHS_BALANCE"]).head(150).tail(20)
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 4906366     2001242      100007             -15            17.0
# 1690801     2001242      100007             -14            17.0
# 2888418     2001242      100007             -13            17.0
# 2196414     2001242      100007             -12            17.0
# 1694281     2001242      100007             -11            17.0
# 2463436     2119973      100007             -77            10.0
# 1987670     2119973      100007             -76            10.0
# 3199534     2119973      100007             -75            10.0
# 2553642     2119973      100007             -74            10.0
# 76767       2119973      100007             -73            10.0
# 8841662     2119973      100007             -72            10.0
# 8594928     2119973      100007             -71            10.0
# 7502151     2119973      100007             -70            10.0
# 4337857     2119973      100007             -69            10.0
# 6989721     2119973      100007             -68            10.0
# 6616247     2462742      100007             -58            12.0
# 80511       2462742      100007             -57            12.0
# 3847889     2462742      100007             -56            12.0
# 4335584     2462742      100007             -55            12.0
# 5323129     2462742      100007             -54            12.0
#
#          CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 4906366                    4.0               Active       0           0
# 1690801                    3.0               Active       0           0
# 2888418                    2.0               Active       0           0
# 2196414                    1.0               Active       0           0
# 1694281                    0.0            Completed       0           0
# 2463436                   10.0               Active       0           0
# 1987670                    9.0               Active       0           0
# 3199534                    8.0               Active       0           0
# 2553642                    7.0               Active       0           0
# 76767                      6.0               Active       0           0
# 8841662                    5.0               Active       0           0
# 8594928                    4.0               Active       0           0
# 7502151                    3.0               Active       0           0
# 4337857                    2.0               Active       0           0
# 6989721                    1.0               Active       0           0
# 6616247                   12.0               Active       0           0
# 80511                     11.0               Active       0           0
# 3847889                   10.0               Active       0           0
# 4335584                    9.0               Active       0           0
# 5323129                    8.0               Active       0           0

# %%
credit_card.sort_values(["SK_ID_CURR", "SK_ID_PREV", "MONTHS_BALANCE"]).query("MONTHS_BALANCE >= -12").head(200).tail(20)
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 1635325     1691588      100077              -4          0.0
# 640195      2628319      100082             -12          0.0
# 3745556     2628319      100082             -11          0.0
# 2997646     2628319      100082             -10          0.0
# 1626848     2628319      100082              -9          0.0
# 2739629     2628319      100082              -8          0.0
# 3357437     2628319      100082              -7          0.0
# 3601018     2628319      100082              -6          0.0
# 1281205     2628319      100082              -5          0.0
# 3817265     2628319      100082              -4          0.0
# 1376246     2628319      100082              -3          0.0
# 173337      2628319      100082              -2          0.0
# 884515      1565121      100083             -12          0.0
# 2430184     1565121      100083             -11          0.0
# 443494      1565121      100083             -10          0.0
# 3057659     1565121      100083              -9          0.0
# 3107419     1565121      100083              -8          0.0
# 1620369     1565121      100083              -7          0.0
# 3008976     1565121      100083              -6          0.0
# 1725589     1565121      100083              -5          0.0
#
#          AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  \
# 1635325                        0                       NaN
# 640195                         0                       0.0
# 3745556                        0                       0.0
# 2997646                        0                       0.0
# 1626848                        0                       0.0
# 2739629                        0                       0.0
# 3357437                        0                       0.0
# 3601018                        0                       0.0
# 1281205                        0                       0.0
# 3817265                        0                       0.0
# 1376246                        0                       0.0
# 173337                         0                       0.0
# 884515                     90000                       NaN
# 2430184                    90000                       NaN
# 443494                     90000                       NaN
# 3057659                    90000                       NaN
# 3107419                    90000                       NaN
# 1620369                    90000                       NaN
# 3008976                    90000                       NaN
# 1725589                    90000                       NaN
#
#          AMT_DRAWINGS_CURRENT  AMT_DRAWINGS_OTHER_CURRENT  \
# 1635325                   0.0                         NaN
# 640195                    0.0                         0.0
# 3745556                   0.0                         0.0
# 2997646                   0.0                         0.0
# 1626848                   0.0                         0.0
# 2739629                   0.0                         0.0
# 3357437                   0.0                         0.0
# 3601018                   0.0                         0.0
# 1281205                   0.0                         0.0
# 3817265                   0.0                         0.0
# 1376246                   0.0                         0.0
# 173337                    0.0                         0.0
# 884515                    0.0                         NaN
# 2430184                   0.0                         NaN
# 443494                    0.0                         NaN
# 3057659                   0.0                         NaN
# 3107419                   0.0                         NaN
# 1620369                   0.0                         NaN
# 3008976                   0.0                         NaN
# 1725589                   0.0                         NaN
#
#          AMT_DRAWINGS_POS_CURRENT  AMT_INST_MIN_REGULARITY     ...      \
# 1635325                       NaN                      0.0     ...
# 640195                        0.0                      0.0     ...
# 3745556                       0.0                      0.0     ...
# 2997646                       0.0                      0.0     ...
# 1626848                       0.0                      0.0     ...
# 2739629                       0.0                      0.0     ...
# 3357437                       0.0                      0.0     ...
# 3601018                       0.0                      0.0     ...
# 1281205                       0.0                      0.0     ...
# 3817265                       0.0                      0.0     ...
# 1376246                       0.0                      0.0     ...
# 173337                        0.0                      0.0     ...
# 884515                        NaN                      0.0     ...
# 2430184                       NaN                      0.0     ...
# 443494                        NaN                      0.0     ...
# 3057659                       NaN                      0.0     ...
# 3107419                       NaN                      0.0     ...
# 1620369                       NaN                      0.0     ...
# 3008976                       NaN                      0.0     ...
# 1725589                       NaN                      0.0     ...
#
#          AMT_RECIVABLE  AMT_TOTAL_RECEIVABLE  CNT_DRAWINGS_ATM_CURRENT  \
# 1635325            0.0                   0.0                       NaN
# 640195             0.0                   0.0                       0.0
# 3745556            0.0                   0.0                       0.0
# 2997646            0.0                   0.0                       0.0
# 1626848            0.0                   0.0                       0.0
# 2739629            0.0                   0.0                       0.0
# 3357437            0.0                   0.0                       0.0
# 3601018            0.0                   0.0                       0.0
# 1281205            0.0                   0.0                       0.0
# 3817265            0.0                   0.0                       0.0
# 1376246            0.0                   0.0                       0.0
# 173337             0.0                   0.0                       0.0
# 884515             0.0                   0.0                       NaN
# 2430184            0.0                   0.0                       NaN
# 443494             0.0                   0.0                       NaN
# 3057659            0.0                   0.0                       NaN
# 3107419            0.0                   0.0                       NaN
# 1620369            0.0                   0.0                       NaN
# 3008976            0.0                   0.0                       NaN
# 1725589            0.0                   0.0                       NaN
#
#          CNT_DRAWINGS_CURRENT  CNT_DRAWINGS_OTHER_CURRENT  \
# 1635325                     0                         NaN
# 640195                      0                         0.0
# 3745556                     0                         0.0
# 2997646                     0                         0.0
# 1626848                     0                         0.0
# 2739629                     0                         0.0
# 3357437                     0                         0.0
# 3601018                     0                         0.0
# 1281205                     0                         0.0
# 3817265                     0                         0.0
# 1376246                     0                         0.0
# 173337                      0                         0.0
# 884515                      0                         NaN
# 2430184                     0                         NaN
# 443494                      0                         NaN
# 3057659                     0                         NaN
# 3107419                     0                         NaN
# 1620369                     0                         NaN
# 3008976                     0                         NaN
# 1725589                     0                         NaN
#
#          CNT_DRAWINGS_POS_CURRENT  CNT_INSTALMENT_MATURE_CUM  \
# 1635325                       NaN                        0.0
# 640195                        0.0                       30.0
# 3745556                       0.0                       30.0
# 2997646                       0.0                       30.0
# 1626848                       0.0                       30.0
# 2739629                       0.0                       30.0
# 3357437                       0.0                       30.0
# 3601018                       0.0                       30.0
# 1281205                       0.0                       30.0
# 3817265                       0.0                       30.0
# 1376246                       0.0                       30.0
# 173337                        0.0                       30.0
# 884515                        NaN                        0.0
# 2430184                       NaN                        0.0
# 443494                        NaN                        0.0
# 3057659                       NaN                        0.0
# 3107419                       NaN                        0.0
# 1620369                       NaN                        0.0
# 3008976                       NaN                        0.0
# 1725589                       NaN                        0.0
#
#          NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 1635325                Active       0           0
# 640195                 Active       0           0
# 3745556                Active       0           0
# 2997646                Active       0           0
# 1626848                Active       0           0
# 2739629                Active       0           0
# 3357437                Active       0           0
# 3601018                Active       0           0
# 1281205                Active       0           0
# 3817265                Active       0           0
# 1376246                Active       0           0
# 173337                 Active       0           0
# 884515                 Active       0           0
# 2430184                Active       0           0
# 443494                 Active       0           0
# 3057659                Active       0           0
# 3107419                Active       0           0
# 1620369                Active       0           0
# 3008976                Active       0           0
# 1725589                Active       0           0
#
# [20 rows x 23 columns]

# %%
bureau.head()
# Out:
#    SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0      215354       5714462        Closed      currency 1         -497
# 1      215354       5714463        Active      currency 1         -208
# 2      215354       5714464        Active      currency 1         -203
# 3      215354       5714465        Active      currency 1         -203
# 4      215354       5714466        Active      currency 1         -629
#
#    CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                   0               -153.0             -153.0
# 1                   0               1075.0                NaN
# 2                   0                528.0                NaN
# 3                   0                  NaN                NaN
# 4                   0               1197.0                NaN
#
#    AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 0                     NaN                   0         91323.0
# 1                     NaN                   0        225000.0
# 2                     NaN                   0        464323.5
# 3                     NaN                   0         90000.0
# 4                 77674.5                   0       2700000.0
#
#    AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 0                  0.0                   NaN                     0.0
# 1             171342.0                   NaN                     0.0
# 2                  NaN                   NaN                     0.0
# 3                  NaN                   NaN                     0.0
# 4                  NaN                   NaN                     0.0
#
#        CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY
# 0  Consumer credit                -131          NaN
# 1      Credit card                 -20          NaN
# 2  Consumer credit                 -16          NaN
# 3      Credit card                 -16          NaN
# 4  Consumer credit                 -21          NaN
